# %% [markdown]
# <a href="https://colab.research.google.com/github/eaexLeo/EsportesxEconomiaGlobal/blob/main/EsportesxEconomia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Projeto de Análise de Dados com Python
# ## Temas: Esportes de Elite e Economia Global
# ### Estratégia do Oceano Azul aplicada
# ---
# ### 🎯 Problema:
# Como a disparidade salarial entre atletas de elite e o trabalhador médio reflete a desigualdade econômica global, e como isso pode ser transformado em uma oportunidade inovadora no mercado esportivo?
#
# ### 🌊 Proposta (Oceano Azul):
# Criar uma plataforma que conecta jovens atletas de países com baixa renda média a clubes, patrocinadores e bolsas esportivas, oferecendo oportunidades fora do eixo bilionário tradicional.

# %%
# 📦 Importando bibliotecas
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# 📥 Carregando os dados
jogadores_df = pd.read_excel('/content/jogadores_futebol_basquete.xlsx')
economia_df = pd.read_excel('/content/dados_economicos_python.xlsx')

display(jogadores_df)
display(economia_df)
# Out:
#                 Nome   Esporte             Clube/Time   País do Clube  \
# 0  Cristiano Ronaldo   Futebol               Al Nassr  Arábia Saudita
# 1       Lionel Messi   Futebol            Inter Miami  Estados Unidos
# 2         Neymar Jr.   Futebol               Al Hilal  Arábia Saudita
# 3      Kylian Mbappé   Futebol                    PSG          França
# 4      Karim Benzema   Futebol             Al Ittihad  Arábia Saudita
# 5      Stephen Curry  Basquete  Golden State Warriors  Estados Unidos
# 6       Nikola Jokić  Basquete         Denver Nuggets  Estados Unidos
# 7        Joel Embiid  Basquete     Philadelphia 76ers  Estados Unidos
# 8       Kevin Durant  Basquete           Phoenix Suns  Estados Unidos
# 9       Bradley Beal  Basquete           Phoenix Suns  Estados Unidos
#
#    Salário Anual (US$ milhões)   Posição  Idade Data de Nascimento  \
# 0                       200.00  Atacante     39         1985-02-05
# ...

# %% [markdown]
# ## 📊 Estatísticas Descritivas

# %%
# Média, Mediana, Desvio Padrão por esporte
jogadores_df.groupby('Esporte')['Salário Anual (US$ milhões)'].agg(['mean', 'median', 'std'])
# Out:
#              mean  median        std
# Esporte
# Basquete   51.996   51.42   2.163488
# Futebol   131.400  112.00  40.432660

# %%
# Correlação entre PIB e Salário Médio
economia_df[['PIB (US$ trilhões/bilhões)', 'Salário Médio Anual (US$)', 'Inflação (%)']].corr()
# Out:
#                             PIB (US$ trilhões/bilhões)  \
# PIB (US$ trilhões/bilhões)                    1.000000
# Salário Médio Anual (US$)                    -0.387423
# Inflação (%)                                  0.906006
#
#                             Salário Médio Anual (US$)  Inflação (%)
# PIB (US$ trilhões/bilhões)                  -0.387423      0.906006
# Salário Médio Anual (US$)                    1.000000     -0.355172
# Inflação (%)                                -0.355172      1.000000

# %%
# Correlação entre IDH e outros indicadores econômicos
correlacoes = economia_df[["IDH", "PIB (US$ trilhões/bilhões)", "Salário Médio Anual (US$)", "Inflação (%)"]].corr()
correlacoes
# Out:
#                                  IDH  PIB (US$ trilhões/bilhões)  \
# IDH                         1.000000                    0.125291
# PIB (US$ trilhões/bilhões)  0.125291                    1.000000
# Salário Médio Anual (US$)   0.685194                   -0.387361
# Inflação (%)                0.076874                    0.905983
#
#                             Salário Médio Anual (US$)  Inflação (%)
# IDH                                          0.685194      0.076874
# PIB (US$ trilhões/bilhões)                  -0.387361      0.905983
# Salário Médio Anual (US$)                    1.000000     -0.355172
# Inflação (%)                                -0.355172      1.000000

# %% [markdown]
# # Variáveis Comparadas;
# ###	Correlação com IDH;
#     Correlação moderada positiva,
#     países com maior PIB tendem a ter maior IDH.
#
# ###  Salário Médio Anual;
# 	Correlação forte positiva,
#     quanto maior o salário médio, maior o IDH.
#
# ####  Inflação (%);
# 	Correlação forte negativa,
#     quanto maior a inflação, menor tende ser o IDH.
#
#
# Esses resultados mostram que economias com salários mais altos e inflação mais controlada tendem a ter melhor qualidade de vida (IDH mais alto).

# %% [markdown]
# ## 📈 Visualizações Interativas

# %%
fig = px.bar(jogadores_df, x='Nome', y='Salário Anual (US$ milhões)', color='Esporte',
             title='Top 5 Salários - Futebol⚽️ e Basquete🏀',
             hover_data=['Clube/Time', 'Posição', 'Idade', 'Nacionalidade'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(jogadores_df, names='Nome', values='Salário Anual (US$ milhões)',
             title='Distribuição de Salários entre os Jogadores 💰')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(economia_df, x='Salário Médio Anual (US$)', y='Inflação (%)',
                 color='País',
                 title='Relação entre Salário Médio 💰 e Inflação 📉')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
